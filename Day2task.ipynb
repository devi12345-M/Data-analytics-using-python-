# %% [markdown]
# <a href="https://colab.research.google.com/github/devi12345-M/Data-analytics-using-python-/blob/main/Day2task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
 print("welcome", name)
greet("glenda")
# Out:
# welcome glenda

# %%
def add(a,b):
    return a+b
result= add(10,20)
print(result)
# Out:
# 30

# %%
def greet():
    print("hi")
greet()
# Out:
# hi

# %%
try:
   num = int( input(" enter Number:"))
   print(num)

except:
   print(" invalid input")
# Out:
#  enter Number:123
# 123

# %%
import numpy as np

marks = np.array([93,67,79,45])

print(marks)
# Out:
# [93 67 79 45]
